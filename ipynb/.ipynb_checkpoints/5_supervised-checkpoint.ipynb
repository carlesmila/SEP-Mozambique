# %% [markdown]
# # Setup

# %%
import warnings
warnings.filterwarnings('ignore')
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import spearmanr
from sklearn.metrics import root_mean_squared_error, r2_score, accuracy_score, f1_score

# %%
# Custom binary scorer
def acc_scorer(y_true, y_pred):
    y_true_bin = [1 if x ==0 else 0 for x in y_true]
    y_pred_bin = [1 if x ==0 else 0 for x in y_pred]
    return accuracy_score(y_true_bin, y_pred_bin)

# %%
# Function to generate a dataframe with the mean (SD) of the scores across CV folds
def prep_cv_reg(file, measure, model, features):
    
    scores = pd.read_csv(file)
    scores['test_rmse'] = -scores['test_rmse']
    
    scores_dict = { 'Outcome': measure,
                    'Model': model,
                    'Features': features,
                    'rho': str(round(scores['test_rho'].mean(), 2)) + ' (' + str(round(scores['test_rho'].std(),2)) + ')',
                    'R2': str(round(scores['test_r2'].mean(),2)) + ' (' + str(round(scores['test_r2'].std(),2)) + ')',
                    'RMSE': f"{round(scores['test_rmse'].mean(),2):,}" + ' (' + f"{round(scores['test_rmse'].std(),2):,}" + ')'
                   
                  }
    scores_df = pd.DataFrame([scores_dict])
    return scores_df

# %%
# Function to generate a dataframe with the mean (SD) of the scores across CV folds
def prep_cv_class(file, measure, model, features):
    
    scores = pd.read_csv(file)
    
    scores_dict = { 'Outcome': measure,
                    'Model': model,
                    'Features': features,
                    'Accuracy': str(round(scores['test_acc'].mean(), 2)) + ' (' + str(round(scores['test_acc'].std(),2)) + ')',
                    'Accuracy group 1': str(round(scores['test_acc_class1'].mean(), 2)) + ' (' + str(round(scores['test_acc_class1'].std(),2)) + ')',
                    'F1 group 1': str(round(scores['test_f1_class1'].mean(), 2)) + ' (' + str(round(scores['test_f1_class1'].std(),2)) + ')'
                  }
    scores_df = pd.DataFrame([scores_dict])
    return scores_df

# %% [markdown]
# # Results

# %% [markdown]
# ## Regression - finetuned

# %%
# Read data
test_rf = pd.read_csv('output/regression_tuning/test_results_rf.csv')
test_rf['Model'] = "RF"
test_xgboost = pd.read_csv('output/regression_tuning/test_results_xgboost.csv')
test_xgboost['Model'] = "XGBoost"

# %%
# Satellite
rf = {
    'model': 'Satellite rf',
    'assets_r2': round(r2_score(test_rf.assets_true, test_rf.assets_sat), 2),
    'assets_p': round(spearmanr(test_rf.assets_true, test_rf.assets_sat)[0], 2),
    'assets_rmse': round(root_mean_squared_error(test_rf.assets_true, test_rf.assets_sat), 2),
    'exp_r2': round(r2_score(test_rf.exp_true, test_rf.exp_sat), 2),
    'exp_p': round(spearmanr(test_rf.exp_true, test_rf.exp_sat)[0], 2),
    'exp_rmse': round(root_mean_squared_error(test_rf.exp_true, test_rf.exp_sat), 2),
    'inc_r2': round(r2_score(test_rf.inc_true, test_rf.inc_sat), 2),
    'inc_p': round(spearmanr(test_rf.inc_true, test_rf.inc_sat)[0], 2),
    'inc_rmse': round(root_mean_squared_error(test_rf.inc_true, test_rf.inc_sat), 2),
}
xgboost = {
    'model': 'Satellite xgboost',
    'assets_r2': round(r2_score(test_xgboost.assets_true, test_xgboost.assets_sat), 2),
    'assets_p': round(spearmanr(test_xgboost.assets_true, test_xgboost.assets_sat)[0], 2),
    'assets_rmse': round(root_mean_squared_error(test_xgboost.assets_true, test_xgboost.assets_sat), 2),
    'exp_r2': round(r2_score(test_xgboost.exp_true, test_xgboost.exp_sat), 2),
    'exp_p': round(spearmanr(test_xgboost.exp_true, test_xgboost.exp_sat)[0], 2),
    'exp_rmse': round(root_mean_squared_error(test_xgboost.exp_true, test_xgboost.exp_sat), 2),
    'inc_r2': round(r2_score(test_xgboost.inc_true, test_xgboost.inc_sat), 2),
    'inc_p': round(spearmanr(test_xgboost.inc_true, test_xgboost.inc_sat)[0], 2),
    'inc_rmse': round(root_mean_squared_error(test_xgboost.inc_true, test_xgboost.inc_sat), 2),
}
satellite = pd.concat([pd.DataFrame(rf, index=[0]), pd.DataFrame(xgboost, index=[0])])
del(rf, xgboost)

# %%
# Outdoor
rf = {
    'model': 'Outdoor rf',
    'assets_r2': round(r2_score(test_rf.assets_true, test_rf.assets_outdoor), 2),
    'assets_p': round(spearmanr(test_rf.assets_true, test_rf.assets_outdoor)[0], 2),
    'assets_rmse': round(root_mean_squared_error(test_rf.assets_true, test_rf.assets_outdoor), 2),
    'exp_r2': round(r2_score(test_rf.exp_true, test_rf.exp_outdoor), 2),
    'exp_p': round(spearmanr(test_rf.exp_true, test_rf.exp_outdoor)[0], 2),
    'exp_rmse': round(root_mean_squared_error(test_rf.exp_true, test_rf.exp_outdoor), 2),
    'inc_r2': round(r2_score(test_rf.inc_true, test_rf.inc_outdoor), 2),
    'inc_p': round(spearmanr(test_rf.inc_true, test_rf.inc_outdoor)[0], 2),
    'inc_rmse': round(root_mean_squared_error(test_rf.inc_true, test_rf.inc_outdoor), 2),
}
xgboost = {
    'model': 'Outdoor xgboost',
    'assets_r2': round(r2_score(test_xgboost.assets_true, test_xgboost.assets_outdoor), 2),
    'assets_p': round(spearmanr(test_xgboost.assets_true, test_xgboost.assets_outdoor)[0], 2),
    'assets_rmse': round(root_mean_squared_error(test_xgboost.assets_true, test_xgboost.assets_outdoor), 2),
    'exp_r2': round(r2_score(test_xgboost.exp_true, test_xgboost.exp_outdoor), 2),
    'exp_p': round(spearmanr(test_xgboost.exp_true, test_xgboost.exp_outdoor)[0], 2),
    'exp_rmse': round(root_mean_squared_error(test_xgboost.exp_true, test_xgboost.exp_outdoor), 2),
    'inc_r2': round(r2_score(test_xgboost.inc_true, test_xgboost.inc_outdoor), 2),
    'inc_p': round(spearmanr(test_xgboost.inc_true, test_xgboost.inc_outdoor)[0], 2),
    'inc_rmse': round(root_mean_squared_error(test_xgboost.inc_true, test_xgboost.inc_outdoor), 2),
}
outdoor = pd.concat([pd.DataFrame(rf, index=[0]), pd.DataFrame(xgboost, index=[0])])
del(rf, xgboost)

# %%
# Complete
rf = {
    'model': 'Complete rf',
    'assets_r2': round(r2_score(test_rf.assets_true, test_rf.assets_all), 2),
    'assets_p': round(spearmanr(test_rf.assets_true, test_rf.assets_all)[0], 2),
    'assets_rmse': round(root_mean_squared_error(test_rf.assets_true, test_rf.assets_all), 2),
    'exp_r2': round(r2_score(test_rf.exp_true, test_rf.exp_all), 2),
    'exp_p': round(spearmanr(test_rf.exp_true, test_rf.exp_all)[0], 2),
    'exp_rmse': round(root_mean_squared_error(test_rf.exp_true, test_rf.exp_all), 2),
    'inc_r2': round(r2_score(test_rf.inc_true, test_rf.inc_all), 2),
    'inc_p': round(spearmanr(test_rf.inc_true, test_rf.inc_all)[0], 2),
    'inc_rmse': round(root_mean_squared_error(test_rf.inc_true, test_rf.inc_all), 2),
}
xgboost = {
    'model': 'Complete xgboost',
    'assets_r2': round(r2_score(test_xgboost.assets_true, test_xgboost.assets_all), 2),
    'assets_p': round(spearmanr(test_xgboost.assets_true, test_xgboost.assets_all)[0], 2),
    'assets_rmse': round(root_mean_squared_error(test_xgboost.assets_true, test_xgboost.assets_all), 2),
    'exp_r2': round(r2_score(test_xgboost.exp_true, test_xgboost.exp_all), 2),
    'exp_p': round(spearmanr(test_xgboost.exp_true, test_xgboost.exp_all)[0], 2),
    'exp_rmse': round(root_mean_squared_error(test_xgboost.exp_true, test_xgboost.exp_all), 2),
    'inc_r2': round(r2_score(test_xgboost.inc_true, test_xgboost.inc_all), 2),
    'inc_p': round(spearmanr(test_xgboost.inc_true, test_xgboost.inc_all)[0], 2),
    'inc_rmse': round(root_mean_squared_error(test_xgboost.inc_true, test_xgboost.inc_all), 2),
}
complete = pd.concat([pd.DataFrame(rf, index=[0]), pd.DataFrame(xgboost, index=[0])])
del(rf, xgboost)

# %%
reg_tuned =  pd.concat([satellite, outdoor, complete])
reg_tuned = reg_tuned[["model", "assets_p", "assets_r2", "assets_rmse", "exp_p", "exp_r2", "exp_rmse", "inc_p", "inc_r2", "inc_rmse"]]
# reg_tuned = reg_tuned.style.format(decimal='.', thousands=',', precision=2).hide(axis="index")
reg_tuned
# Out:
#                model  assets_p  assets_r2  assets_rmse  exp_p  exp_r2  \
# 0       Satellite rf      0.51       0.30         0.44   0.35    0.14
# 0  Satellite xgboost      0.54       0.30         0.43   0.34    0.10
# 0         Outdoor rf      0.70       0.50         0.37   0.45    0.24
# 0    Outdoor xgboost      0.70       0.49         0.37   0.42    0.19
# 0        Complete rf      0.85       0.70         0.28   0.57    0.38
# 0   Complete xgboost      0.84       0.70         0.29   0.56    0.36
#
#    exp_rmse  inc_p  inc_r2  inc_rmse
# 0   5505.40   0.30    0.05  12062.84
# 0   5635.83   0.28    0.03  12189.78
# 0   5162.62   0.41    0.10  11735.23
# 0   5353.11   0.41    0.09  11817.62
# 0   4684.25   0.50    0.16  11323.67
# 0   4752.38   0.50    0.17  11237.70

# %%
del(test_rf, test_xgboost)

# %% [markdown]
# ## Regression - not finetuned

# %%
# Read data
test_rf = pd.read_csv('output/regression_notuning/test_results_rf.csv')
test_rf['Model'] = "RF"
test_xgboost = pd.read_csv('output/regression_notuning/test_results_xgboost.csv')
test_xgboost['Model'] = "XGBoost"

# %%
# Satellite
rf = {
    'model': 'Satellite rf',
    'assets_r2': round(r2_score(test_rf.assets_true, test_rf.assets_sat), 2),
    'assets_p': round(spearmanr(test_rf.assets_true, test_rf.assets_sat)[0], 2),
    'assets_rmse': round(root_mean_squared_error(test_rf.assets_true, test_rf.assets_sat), 2),
    'exp_r2': round(r2_score(test_rf.exp_true, test_rf.exp_sat), 2),
    'exp_p': round(spearmanr(test_rf.exp_true, test_rf.exp_sat)[0], 2),
    'exp_rmse': round(root_mean_squared_error(test_rf.exp_true, test_rf.exp_sat), 2),
    'inc_r2': round(r2_score(test_rf.inc_true, test_rf.inc_sat), 2),
    'inc_p': round(spearmanr(test_rf.inc_true, test_rf.inc_sat)[0], 2),
    'inc_rmse': round(root_mean_squared_error(test_rf.inc_true, test_rf.inc_sat), 2),
}
xgboost = {
    'model': 'Satellite xgboost',
    'assets_r2': round(r2_score(test_xgboost.assets_true, test_xgboost.assets_sat), 2),
    'assets_p': round(spearmanr(test_xgboost.assets_true, test_xgboost.assets_sat)[0], 2),
    'assets_rmse': round(root_mean_squared_error(test_xgboost.assets_true, test_xgboost.assets_sat), 2),
    'exp_r2': round(r2_score(test_xgboost.exp_true, test_xgboost.exp_sat), 2),
    'exp_p': round(spearmanr(test_xgboost.exp_true, test_xgboost.exp_sat)[0], 2),
    'exp_rmse': round(root_mean_squared_error(test_xgboost.exp_true, test_xgboost.exp_sat), 2),
    'inc_r2': round(r2_score(test_xgboost.inc_true, test_xgboost.inc_sat), 2),
    'inc_p': round(spearmanr(test_xgboost.inc_true, test_xgboost.inc_sat)[0], 2),
    'inc_rmse': round(root_mean_squared_error(test_xgboost.inc_true, test_xgboost.inc_sat), 2),
}
satellite = pd.concat([pd.DataFrame(rf, index=[0]), pd.DataFrame(xgboost, index=[0])])
del(rf, xgboost)

# %%
# Outdoor
rf = {
    'model': 'Outdoor rf',
    'assets_r2': round(r2_score(test_rf.assets_true, test_rf.assets_outdoor), 2),
    'assets_p': round(spearmanr(test_rf.assets_true, test_rf.assets_outdoor)[0], 2),
    'assets_rmse': round(root_mean_squared_error(test_rf.assets_true, test_rf.assets_outdoor), 2),
    'exp_r2': round(r2_score(test_rf.exp_true, test_rf.exp_outdoor), 2),
    'exp_p': round(spearmanr(test_rf.exp_true, test_rf.exp_outdoor)[0], 2),
    'exp_rmse': round(root_mean_squared_error(test_rf.exp_true, test_rf.exp_outdoor), 2),
    'inc_r2': round(r2_score(test_rf.inc_true, test_rf.inc_outdoor), 2),
    'inc_p': round(spearmanr(test_rf.inc_true, test_rf.inc_outdoor)[0], 2),
    'inc_rmse': round(root_mean_squared_error(test_rf.inc_true, test_rf.inc_outdoor), 2),
}
xgboost = {
    'model': 'Outdoor xgboost',
    'assets_r2': round(r2_score(test_xgboost.assets_true, test_xgboost.assets_outdoor), 2),
    'assets_p': round(spearmanr(test_xgboost.assets_true, test_xgboost.assets_outdoor)[0], 2),
    'assets_rmse': round(root_mean_squared_error(test_xgboost.assets_true, test_xgboost.assets_outdoor), 2),
    'exp_r2': round(r2_score(test_xgboost.exp_true, test_xgboost.exp_outdoor), 2),
    'exp_p': round(spearmanr(test_xgboost.exp_true, test_xgboost.exp_outdoor)[0], 2),
    'exp_rmse': round(root_mean_squared_error(test_xgboost.exp_true, test_xgboost.exp_outdoor), 2),
    'inc_r2': round(r2_score(test_xgboost.inc_true, test_xgboost.inc_outdoor), 2),
    'inc_p': round(spearmanr(test_xgboost.inc_true, test_xgboost.inc_outdoor)[0], 2),
    'inc_rmse': round(root_mean_squared_error(test_xgboost.inc_true, test_xgboost.inc_outdoor), 2),
}
outdoor = pd.concat([pd.DataFrame(rf, index=[0]), pd.DataFrame(xgboost, index=[0])])
del(rf, xgboost)

# %%
# Complete
rf = {
    'model': 'Complete rf',
    'assets_r2': round(r2_score(test_rf.assets_true, test_rf.assets_all), 2),
    'assets_p': round(spearmanr(test_rf.assets_true, test_rf.assets_all)[0], 2),
    'assets_rmse': round(root_mean_squared_error(test_rf.assets_true, test_rf.assets_all), 2),
    'exp_r2': round(r2_score(test_rf.exp_true, test_rf.exp_all), 2),
    'exp_p': round(spearmanr(test_rf.exp_true, test_rf.exp_all)[0], 2),
    'exp_rmse': round(root_mean_squared_error(test_rf.exp_true, test_rf.exp_all), 2),
    'inc_r2': round(r2_score(test_rf.inc_true, test_rf.inc_all), 2),
    'inc_p': round(spearmanr(test_rf.inc_true, test_rf.inc_all)[0], 2),
    'inc_rmse': round(root_mean_squared_error(test_rf.inc_true, test_rf.inc_all), 2),
}
xgboost = {
    'model': 'Complete xgboost',
    'assets_r2': round(r2_score(test_xgboost.assets_true, test_xgboost.assets_all), 2),
    'assets_p': round(spearmanr(test_xgboost.assets_true, test_xgboost.assets_all)[0], 2),
    'assets_rmse': round(root_mean_squared_error(test_xgboost.assets_true, test_xgboost.assets_all), 2),
    'exp_r2': round(r2_score(test_xgboost.exp_true, test_xgboost.exp_all), 2),
    'exp_p': round(spearmanr(test_xgboost.exp_true, test_xgboost.exp_all)[0], 2),
    'exp_rmse': round(root_mean_squared_error(test_xgboost.exp_true, test_xgboost.exp_all), 2),
    'inc_r2': round(r2_score(test_xgboost.inc_true, test_xgboost.inc_all), 2),
    'inc_p': round(spearmanr(test_xgboost.inc_true, test_xgboost.inc_all)[0], 2),
    'inc_rmse': round(root_mean_squared_error(test_xgboost.inc_true, test_xgboost.inc_all), 2),
}
complete = pd.concat([pd.DataFrame(rf, index=[0]), pd.DataFrame(xgboost, index=[0])])
del(rf, xgboost)

# %%
reg_notuned =  pd.concat([satellite, outdoor, complete])
reg_notuned = reg_notuned[["model", "assets_p", "assets_r2", "assets_rmse", "exp_p", "exp_r2", "exp_rmse", "inc_p", "inc_r2", "inc_rmse"]]
# reg_notuned = reg_notuned.style.format(decimal='.', thousands=',', precision=2).hide(axis="index")
reg_notuned
# Out:
#                model  assets_p  assets_r2  assets_rmse  exp_p  exp_r2  \
# 0       Satellite rf      0.47       0.26         0.45   0.29    0.07
# 0  Satellite xgboost      0.48       0.26         0.45   0.30    0.06
# 0         Outdoor rf      0.70       0.47         0.38   0.45    0.21
# 0    Outdoor xgboost      0.68       0.45         0.39   0.42    0.20
# 0        Complete rf      0.83       0.65         0.31   0.53    0.35
# 0   Complete xgboost      0.83       0.67         0.30   0.49    0.30
#
#    exp_rmse  inc_p  inc_r2  inc_rmse
# 0   5737.62   0.26    0.03  12164.88
# 0   5769.44   0.27    0.03  12186.65
# 0   5292.54   0.34    0.06  11964.40
# 0   5310.43   0.36    0.05  12059.62
# 0   4786.93   0.43    0.14  11480.42
# 0   4979.12   0.43    0.12  11622.79

# %%
# print(finaltable.to_latex())

# %%
del(test_rf, test_xgboost)

# %% [markdown]
# ## Classification - Finetuned

# %%
# Read data
test_rf = pd.read_csv('output/classification_tuning/test_results_rf.csv')
test_rf['exp_cat3'] = [0 if x=='bottom40' else 1 if x=='mid40' else 2 for x in test_rf['exp_cat3']]
test_rf['inc_cat3'] = [0 if x=='bottom40' else 1 if x=='mid40' else 2 for x in test_rf['inc_cat3']]
test_rf['assets_cat3'] = [0 if x=='bottom40' else 1 if x=='mid40' else 2 for x in test_rf['assets_cat3']]
test_rf['Model'] = "RF"

test_xgboost = pd.read_csv('output/classification_tuning/test_results_xgboost.csv')
test_xgboost['exp_cat3'] = [0 if x=='bottom40' else 1 if x=='mid40' else 2 for x in test_xgboost['exp_cat3']]
test_xgboost['inc_cat3'] = [0 if x=='bottom40' else 1 if x=='mid40' else 2 for x in test_xgboost['inc_cat3']]
test_xgboost['assets_cat3'] = [0 if x=='bottom40' else 1 if x=='mid40' else 2 for x in test_xgboost['assets_cat3']]
test_xgboost['Model'] = "XGBoost"

# %%
# Satellite
rf = {
    'model': 'Satellite rf',
    'assets_acc': round(accuracy_score(test_rf.assets_cat3, test_rf.assets_sat), 2),
    'assets_acc1': round(acc_scorer(test_rf.assets_cat3, test_rf.assets_sat), 2),
    'assets_f11': round(f1_score(test_rf.assets_cat3, test_rf.assets_sat, average=None)[0], 2),
    'exp_acc': round(accuracy_score(test_rf.exp_cat3, test_rf.exp_sat), 2),
    'exp_acc1': round(acc_scorer(test_rf.exp_cat3, test_rf.exp_sat), 2),
    'exp_f11': round(f1_score(test_rf.exp_cat3, test_rf.exp_sat, average=None)[0], 2),
    'inc_acc': round(accuracy_score(test_rf.inc_cat3, test_rf.inc_sat), 2),
    'inc_acc1': round(acc_scorer(test_rf.inc_cat3, test_rf.inc_sat), 2),
    'inc_f11': round(f1_score(test_rf.inc_cat3, test_rf.inc_sat, average=None)[0], 2),
}
xgboost = {
    'model': 'Satellite xgboost',
    'assets_acc': round(accuracy_score(test_xgboost.assets_cat3, test_xgboost.assets_sat), 2),
    'assets_acc1': round(acc_scorer(test_xgboost.assets_cat3, test_xgboost.assets_sat), 2),
    'assets_f11': round(f1_score(test_xgboost.assets_cat3, test_xgboost.assets_sat, average=None)[0], 2),
    'exp_acc': round(accuracy_score(test_xgboost.exp_cat3, test_xgboost.exp_sat), 2),
    'exp_acc1': round(acc_scorer(test_xgboost.exp_cat3, test_xgboost.exp_sat), 2),
    'exp_f11': round(f1_score(test_xgboost.exp_cat3, test_xgboost.exp_sat, average=None)[0], 2),
    'inc_acc': round(accuracy_score(test_xgboost.inc_cat3, test_xgboost.inc_sat), 2),
    'inc_acc1': round(acc_scorer(test_xgboost.inc_cat3, test_xgboost.inc_sat), 2),
    'inc_f11': round(f1_score(test_xgboost.inc_cat3, test_xgboost.inc_sat, average=None)[0], 2),
}
satellite = pd.concat([pd.DataFrame(rf, index=[0]), pd.DataFrame(xgboost, index=[0])])
del(rf, xgboost)

# %%
# Outdoor
rf = {
    'model': 'Outdoor rf',
    'assets_acc': round(accuracy_score(test_rf.assets_cat3, test_rf.assets_outdoor), 2),
    'assets_acc1': round(acc_scorer(test_rf.assets_cat3, test_rf.assets_outdoor), 2),
    'assets_f11': round(f1_score(test_rf.assets_cat3, test_rf.assets_outdoor, average=None)[0], 2),
    'exp_acc': round(accuracy_score(test_rf.exp_cat3, test_rf.exp_outdoor), 2),
    'exp_acc1': round(acc_scorer(test_rf.exp_cat3, test_rf.exp_outdoor), 2),
    'exp_f11': round(f1_score(test_rf.exp_cat3, test_rf.exp_outdoor, average=None)[0], 2),
    'inc_acc': round(accuracy_score(test_rf.inc_cat3, test_rf.inc_outdoor), 2),
    'inc_acc1': round(acc_scorer(test_rf.inc_cat3, test_rf.inc_outdoor), 2),
    'inc_f11': round(f1_score(test_rf.inc_cat3, test_rf.inc_outdoor, average=None)[0], 2),
}
xgboost = {
    'model': 'Outdoor xgboost',
    'assets_acc': round(accuracy_score(test_xgboost.assets_cat3, test_xgboost.assets_outdoor), 2),
    'assets_acc1': round(acc_scorer(test_xgboost.assets_cat3, test_xgboost.assets_outdoor), 2),
    'assets_f11': round(f1_score(test_xgboost.assets_cat3, test_xgboost.assets_outdoor, average=None)[0], 2),
    'exp_acc': round(accuracy_score(test_xgboost.exp_cat3, test_xgboost.exp_outdoor), 2),
    'exp_acc1': round(acc_scorer(test_xgboost.exp_cat3, test_xgboost.exp_outdoor), 2),
    'exp_f11': round(f1_score(test_xgboost.exp_cat3, test_xgboost.exp_outdoor, average=None)[0], 2),
    'inc_acc': round(accuracy_score(test_xgboost.inc_cat3, test_xgboost.inc_outdoor), 2),
    'inc_acc1': round(acc_scorer(test_xgboost.inc_cat3, test_xgboost.inc_outdoor), 2),
    'inc_f11': round(f1_score(test_xgboost.inc_cat3, test_xgboost.inc_outdoor, average=None)[0], 2),
}
outdoor = pd.concat([pd.DataFrame(rf, index=[0]), pd.DataFrame(xgboost, index=[0])])
del(rf, xgboost)

# %%
# Complete
rf = {
    'model': 'Complete rf',
    'assets_acc': round(accuracy_score(test_rf.assets_cat3, test_rf.assets_all), 2),
    'assets_acc1': round(acc_scorer(test_rf.assets_cat3, test_rf.assets_all), 2),
    'assets_f11': round(f1_score(test_rf.assets_cat3, test_rf.assets_all, average=None)[0], 2),
    'exp_acc': round(accuracy_score(test_rf.exp_cat3, test_rf.exp_all), 2),
    'exp_acc1': round(acc_scorer(test_rf.exp_cat3, test_rf.exp_all), 2),
    'exp_f11': round(f1_score(test_rf.exp_cat3, test_rf.exp_all, average=None)[0], 2),
    'inc_acc': round(accuracy_score(test_rf.inc_cat3, test_rf.inc_all), 2),
    'inc_acc1': round(acc_scorer(test_rf.inc_cat3, test_rf.inc_all), 2),
    'inc_f11': round(f1_score(test_rf.inc_cat3, test_rf.inc_all, average=None)[0], 2),
}
xgboost = {
    'model': 'Complete xgboost',
    'assets_acc': round(accuracy_score(test_xgboost.assets_cat3, test_xgboost.assets_all), 2),
    'assets_acc1': round(acc_scorer(test_xgboost.assets_cat3, test_xgboost.assets_all), 2),
    'assets_f11': round(f1_score(test_xgboost.assets_cat3, test_xgboost.assets_all, average=None)[0], 2),
    'exp_acc': round(accuracy_score(test_xgboost.exp_cat3, test_xgboost.exp_all), 2),
    'exp_acc1': round(acc_scorer(test_xgboost.exp_cat3, test_xgboost.exp_all), 2),
    'exp_f11': round(f1_score(test_xgboost.exp_cat3, test_xgboost.exp_all, average=None)[0], 2),
    'inc_acc': round(accuracy_score(test_xgboost.inc_cat3, test_xgboost.inc_all), 2),
    'inc_acc1': round(acc_scorer(test_xgboost.inc_cat3, test_xgboost.inc_all), 2),
    'inc_f11': round(f1_score(test_xgboost.inc_cat3, test_xgboost.inc_all, average=None)[0], 2),
}
complete = pd.concat([pd.DataFrame(rf, index=[0]), pd.DataFrame(xgboost, index=[0])])
del(rf, xgboost)

# %%
class_tuned =  pd.concat([satellite, outdoor, complete])
class_tuned = class_tuned[["model", "assets_acc", "assets_acc1", "assets_f11",
                               "exp_acc", "exp_acc1", "exp_f11",
                               "inc_acc", "inc_acc1", "inc_f11"]]
# class_tuned = class_tuned.style.format(decimal='.', thousands=',', precision=2).hide(axis="index")
class_tuned
# Out:
#                model  assets_acc  assets_acc1  assets_f11  exp_acc  exp_acc1  \
# 0       Satellite rf        0.59         0.71        0.61     0.47      0.63
# 0  Satellite xgboost        0.58         0.73        0.61     0.47      0.64
# 0         Outdoor rf        0.59         0.73        0.68     0.50      0.66
# 0    Outdoor xgboost        0.59         0.73        0.67     0.47      0.66
# 0        Complete rf        0.75         0.86        0.83     0.61      0.71
# 0   Complete xgboost        0.74         0.86        0.83     0.61      0.74
#
#    exp_f11  inc_acc  inc_acc1  inc_f11
# 0     0.47     0.47      0.62     0.51
# 0     0.50     0.49      0.65     0.55
# 0     0.58     0.51      0.66     0.55
# 0     0.54     0.44      0.57     0.47
# 0     0.64     0.58      0.68     0.62
# 0     0.68     0.55      0.67     0.61

# %% [markdown]
# ## Classification - Not finetuned

# %%
# Read data
test_rf = pd.read_csv('output/classification_notuning/test_results_rf.csv')
test_rf['exp_cat3'] = [0 if x=='bottom40' else 1 if x=='mid40' else 2 for x in test_rf['exp_cat3']]
test_rf['inc_cat3'] = [0 if x=='bottom40' else 1 if x=='mid40' else 2 for x in test_rf['inc_cat3']]
test_rf['assets_cat3'] = [0 if x=='bottom40' else 1 if x=='mid40' else 2 for x in test_rf['assets_cat3']]
test_rf['Model'] = "RF"

test_xgboost = pd.read_csv('output/classification_notuning/test_results_xgboost.csv')
test_xgboost['exp_cat3'] = [0 if x=='bottom40' else 1 if x=='mid40' else 2 for x in test_xgboost['exp_cat3']]
test_xgboost['inc_cat3'] = [0 if x=='bottom40' else 1 if x=='mid40' else 2 for x in test_xgboost['inc_cat3']]
test_xgboost['assets_cat3'] = [0 if x=='bottom40' else 1 if x=='mid40' else 2 for x in test_xgboost['assets_cat3']]
test_xgboost['Model'] = "XGBoost"

# %%
# Satellite
rf = {
    'model': 'Satellite rf',
    'assets_acc': round(accuracy_score(test_rf.assets_cat3, test_rf.assets_sat), 2),
    'assets_acc1': round(acc_scorer(test_rf.assets_cat3, test_rf.assets_sat), 2),
    'assets_f11': round(f1_score(test_rf.assets_cat3, test_rf.assets_sat, average=None)[0], 2),
    'exp_acc': round(accuracy_score(test_rf.exp_cat3, test_rf.exp_sat), 2),
    'exp_acc1': round(acc_scorer(test_rf.exp_cat3, test_rf.exp_sat), 2),
    'exp_f11': round(f1_score(test_rf.exp_cat3, test_rf.exp_sat, average=None)[0], 2),
    'inc_acc': round(accuracy_score(test_rf.inc_cat3, test_rf.inc_sat), 2),
    'inc_acc1': round(acc_scorer(test_rf.inc_cat3, test_rf.inc_sat), 2),
    'inc_f11': round(f1_score(test_rf.inc_cat3, test_rf.inc_sat, average=None)[0], 2),
}
xgboost = {
    'model': 'Satellite xgboost',
    'assets_acc': round(accuracy_score(test_xgboost.assets_cat3, test_xgboost.assets_sat), 2),
    'assets_acc1': round(acc_scorer(test_xgboost.assets_cat3, test_xgboost.assets_sat), 2),
    'assets_f11': round(f1_score(test_xgboost.assets_cat3, test_xgboost.assets_sat, average=None)[0], 2),
    'exp_acc': round(accuracy_score(test_xgboost.exp_cat3, test_xgboost.exp_sat), 2),
    'exp_acc1': round(acc_scorer(test_xgboost.exp_cat3, test_xgboost.exp_sat), 2),
    'exp_f11': round(f1_score(test_xgboost.exp_cat3, test_xgboost.exp_sat, average=None)[0], 2),
    'inc_acc': round(accuracy_score(test_xgboost.inc_cat3, test_xgboost.inc_sat), 2),
    'inc_acc1': round(acc_scorer(test_xgboost.inc_cat3, test_xgboost.inc_sat), 2),
    'inc_f11': round(f1_score(test_xgboost.inc_cat3, test_xgboost.inc_sat, average=None)[0], 2),
}
satellite = pd.concat([pd.DataFrame(rf, index=[0]), pd.DataFrame(xgboost, index=[0])])
del(rf, xgboost)

# %%
# Outdoor
rf = {
    'model': 'Outdoor rf',
    'assets_acc': round(accuracy_score(test_rf.assets_cat3, test_rf.assets_outdoor), 2),
    'assets_acc1': round(acc_scorer(test_rf.assets_cat3, test_rf.assets_outdoor), 2),
    'assets_f11': round(f1_score(test_rf.assets_cat3, test_rf.assets_outdoor, average=None)[0], 2),
    'exp_acc': round(accuracy_score(test_rf.exp_cat3, test_rf.exp_outdoor), 2),
    'exp_acc1': round(acc_scorer(test_rf.exp_cat3, test_rf.exp_outdoor), 2),
    'exp_f11': round(f1_score(test_rf.exp_cat3, test_rf.exp_outdoor, average=None)[0], 2),
    'inc_acc': round(accuracy_score(test_rf.inc_cat3, test_rf.inc_outdoor), 2),
    'inc_acc1': round(acc_scorer(test_rf.inc_cat3, test_rf.inc_outdoor), 2),
    'inc_f11': round(f1_score(test_rf.inc_cat3, test_rf.inc_outdoor, average=None)[0], 2),
}
xgboost = {
    'model': 'Outdoor xgboost',
    'assets_acc': round(accuracy_score(test_xgboost.assets_cat3, test_xgboost.assets_outdoor), 2),
    'assets_acc1': round(acc_scorer(test_xgboost.assets_cat3, test_xgboost.assets_outdoor), 2),
    'assets_f11': round(f1_score(test_xgboost.assets_cat3, test_xgboost.assets_outdoor, average=None)[0], 2),
    'exp_acc': round(accuracy_score(test_xgboost.exp_cat3, test_xgboost.exp_outdoor), 2),
    'exp_acc1': round(acc_scorer(test_xgboost.exp_cat3, test_xgboost.exp_outdoor), 2),
    'exp_f11': round(f1_score(test_xgboost.exp_cat3, test_xgboost.exp_outdoor, average=None)[0], 2),
    'inc_acc': round(accuracy_score(test_xgboost.inc_cat3, test_xgboost.inc_outdoor), 2),
    'inc_acc1': round(acc_scorer(test_xgboost.inc_cat3, test_xgboost.inc_outdoor), 2),
    'inc_f11': round(f1_score(test_xgboost.inc_cat3, test_xgboost.inc_outdoor, average=None)[0], 2),
}
outdoor = pd.concat([pd.DataFrame(rf, index=[0]), pd.DataFrame(xgboost, index=[0])])
del(rf, xgboost)

# %%
# Complete
rf = {
    'model': 'Complete rf',
    'assets_acc': round(accuracy_score(test_rf.assets_cat3, test_rf.assets_all), 2),
    'assets_acc1': round(acc_scorer(test_rf.assets_cat3, test_rf.assets_all), 2),
    'assets_f11': round(f1_score(test_rf.assets_cat3, test_rf.assets_all, average=None)[0], 2),
    'exp_acc': round(accuracy_score(test_rf.exp_cat3, test_rf.exp_all), 2),
    'exp_acc1': round(acc_scorer(test_rf.exp_cat3, test_rf.exp_all), 2),
    'exp_f11': round(f1_score(test_rf.exp_cat3, test_rf.exp_all, average=None)[0], 2),
    'inc_acc': round(accuracy_score(test_rf.inc_cat3, test_rf.inc_all), 2),
    'inc_acc1': round(acc_scorer(test_rf.inc_cat3, test_rf.inc_all), 2),
    'inc_f11': round(f1_score(test_rf.inc_cat3, test_rf.inc_all, average=None)[0], 2),
}
xgboost = {
    'model': 'Complete xgboost',
    'assets_acc': round(accuracy_score(test_xgboost.assets_cat3, test_xgboost.assets_all), 2),
    'assets_acc1': round(acc_scorer(test_xgboost.assets_cat3, test_xgboost.assets_all), 2),
    'assets_f11': round(f1_score(test_xgboost.assets_cat3, test_xgboost.assets_all, average=None)[0], 2),
    'exp_acc': round(accuracy_score(test_xgboost.exp_cat3, test_xgboost.exp_all), 2),
    'exp_acc1': round(acc_scorer(test_xgboost.exp_cat3, test_xgboost.exp_all), 2),
    'exp_f11': round(f1_score(test_xgboost.exp_cat3, test_xgboost.exp_all, average=None)[0], 2),
    'inc_acc': round(accuracy_score(test_xgboost.inc_cat3, test_xgboost.inc_all), 2),
    'inc_acc1': round(acc_scorer(test_xgboost.inc_cat3, test_xgboost.inc_all), 2),
    'inc_f11': round(f1_score(test_xgboost.inc_cat3, test_xgboost.inc_all, average=None)[0], 2),
}
complete = pd.concat([pd.DataFrame(rf, index=[0]), pd.DataFrame(xgboost, index=[0])])
del(rf, xgboost)

# %%
class_notuned =  pd.concat([satellite, outdoor, complete])
class_notuned = class_notuned[["model", "assets_acc", "assets_acc1", "assets_f11",
                               "exp_acc", "exp_acc1", "exp_f11",
                               "inc_acc", "inc_acc1", "inc_f11"]]
# class_notuned = class_notuned.style.format(decimal='.', thousands=',', precision=2).hide(axis="index")
class_notuned
# Out:
#                model  assets_acc  assets_acc1  assets_f11  exp_acc  exp_acc1  \
# 0       Satellite rf        0.57         0.68        0.57     0.48      0.65
# 0  Satellite xgboost        0.55         0.67        0.58     0.49      0.64
# 0         Outdoor rf        0.62         0.74        0.69     0.54      0.69
# 0    Outdoor xgboost        0.62         0.75        0.70     0.53      0.68
# 0        Complete rf        0.71         0.83        0.80     0.56      0.69
# 0   Complete xgboost        0.74         0.85        0.82     0.58      0.69
#
#    exp_f11  inc_acc  inc_acc1  inc_f11
# 0     0.51     0.46      0.60     0.49
# 0     0.50     0.52      0.65     0.55
# 0     0.59     0.45      0.61     0.50
# 0     0.58     0.47      0.60     0.53
# 0     0.60     0.53      0.66     0.58
# 0     0.62     0.53      0.65     0.59

# %% [markdown]
# ## Regression - Not finetuned, resampling

# %%
# Assets RF
assets_rf_satellite = prep_cv_reg('output/regression_resampling/assets_satellite_rf.csv', 'Assets', 'RF','Satellite')
assets_rf_outdoor = prep_cv_reg('output/regression_resampling/assets_outdoor_rf.csv', 'Assets', 'RF','Outdoor')
assets_rf_all = prep_cv_reg('output/regression_resampling/assets_all_rf.csv', 'Assets', 'RF','All')

# Assets XGBoost
assets_xgboost_satellite = prep_cv_reg('output/regression_resampling/assets_satellite_xgboost.csv', 'Assets', 'XGBoost','Satellite')
assets_xgboost_outdoor = prep_cv_reg('output/regression_resampling/assets_outdoor_xgboost.csv', 'Assets', 'XGBoost','Outdoor')
assets_xgboost_all = prep_cv_reg('output/regression_resampling/assets_all_xgboost.csv', 'Assets', 'XGBoost','All')

# Expenditure RF
exp_rf_satellite = prep_cv_reg('output/regression_resampling/exp_satellite_rf.csv', 'Expenditure', 'RF','Satellite')
exp_rf_outdoor = prep_cv_reg('output/regression_resampling/exp_outdoor_rf.csv', 'Expenditure', 'RF','Outdoor')
exp_rf_all = prep_cv_reg('output/regression_resampling/exp_all_rf.csv', 'Expenditure', 'RF','All')

# Expenditure XGBoost
exp_xgboost_satellite = prep_cv_reg('output/regression_resampling/exp_satellite_xgboost.csv', 'Expenditure', 'XGBoost','Satellite')
exp_xgboost_outdoor = prep_cv_reg('output/regression_resampling/exp_outdoor_xgboost.csv', 'Expenditure', 'XGBoost','Outdoor')
exp_xgboost_all = prep_cv_reg('output/regression_resampling/exp_all_xgboost.csv', 'Expenditure', 'XGBoost','All')

# Income RF
inc_rf_satellite = prep_cv_reg('output/regression_resampling/inc_satellite_rf.csv', 'Income', 'RF','Satellite')
inc_rf_outdoor = prep_cv_reg('output/regression_resampling/inc_outdoor_rf.csv', 'Income', 'RF','Outdoor')
inc_rf_all = prep_cv_reg('output/regression_resampling/inc_all_rf.csv', 'Income', 'RF','All')

# Income XGBoost
inc_xgboost_satellite = prep_cv_reg('output/regression_resampling/inc_satellite_xgboost.csv', 'Income', 'XGBoost','Satellite')
inc_xgboost_outdoor = prep_cv_reg('output/regression_resampling/inc_outdoor_xgboost.csv', 'Income', 'XGBoost','Outdoor')
inc_xgboost_all = prep_cv_reg('output/regression_resampling/inc_all_xgboost.csv', 'Income', 'XGBoost','All')

# Merge and show
reg_resamp = pd.concat([assets_rf_satellite, assets_rf_outdoor, assets_rf_all,
                        assets_xgboost_satellite, assets_xgboost_outdoor, assets_xgboost_all,
                        exp_rf_satellite, exp_rf_outdoor, exp_rf_all,
                        exp_xgboost_satellite, exp_xgboost_outdoor, exp_xgboost_all,
                        inc_rf_satellite, inc_rf_outdoor, inc_rf_all,
                        inc_xgboost_satellite, inc_xgboost_outdoor, inc_xgboost_all],
                        ignore_index=True)
reg_resamp
# Out:
#         Outcome    Model   Features          rho           R2  \
# 0        Assets       RF  Satellite  0.48 (0.06)  0.26 (0.05)
# 1        Assets       RF    Outdoor  0.66 (0.03)  0.44 (0.04)
# 2        Assets       RF        All  0.79 (0.03)  0.62 (0.04)
# 3        Assets  XGBoost  Satellite  0.48 (0.06)  0.26 (0.05)
# 4        Assets  XGBoost    Outdoor  0.66 (0.04)  0.44 (0.04)
# 5        Assets  XGBoost        All   0.8 (0.03)  0.63 (0.04)
# 6   Expenditure       RF  Satellite  0.39 (0.07)   0.1 (0.05)
# 7   Expenditure       RF    Outdoor  0.49 (0.03)   0.2 (0.06)
# 8   Expenditure       RF        All  0.59 (0.04)  0.28 (0.08)
# 9   Expenditure  XGBoost  Satellite  0.37 (0.07)  0.09 (0.04)
# 10  Expenditure  XGBoost    Outdoor  0.48 (0.04)  0.18 (0.06)
# 11  Expenditure  XGBoost        All  0.56 (0.05)  0.26 (0.09)
# 12       Income       RF  Satellite  0.33 (0.09)  0.04 (0.05)
# 13       Income       RF    Outdoor  0.37 (0.06)   0.1 (0.05)
# ...

# %% [markdown]
# ## Classification - Not finetuned, resampling

# %%
# Assets RF
assets_rf_satellite = prep_cv_class('output/classification_resampling/assets_satellite_rf.csv', 'Assets', 'RF','Satellite')
assets_rf_outdoor = prep_cv_class('output/classification_resampling/assets_outdoor_rf.csv', 'Assets', 'RF','Outdoor')
assets_rf_all = prep_cv_class('output/classification_resampling/assets_all_rf.csv', 'Assets', 'RF','All')

# Assets XGBoost
assets_xgboost_satellite = prep_cv_class('output/classification_resampling/assets_satellite_xgboost.csv', 'Assets', 'XGBoost','Satellite')
assets_xgboost_outdoor = prep_cv_class('output/classification_resampling/assets_outdoor_xgboost.csv', 'Assets', 'XGBoost','Outdoor')
assets_xgboost_all = prep_cv_class('output/classification_resampling/assets_all_xgboost.csv', 'Assets', 'XGBoost','All')

# Expenditure RF
exp_rf_satellite = prep_cv_class('output/classification_resampling/exp_satellite_rf.csv', 'Expenditure', 'RF','Satellite')
exp_rf_outdoor = prep_cv_class('output/classification_resampling/exp_outdoor_rf.csv', 'Expenditure', 'RF','Outdoor')
exp_rf_all = prep_cv_class('output/classification_resampling/exp_all_rf.csv', 'Expenditure', 'RF','All')

# Expenditure XGBoost
exp_xgboost_satellite = prep_cv_class('output/classification_resampling/exp_satellite_xgboost.csv', 'Expenditure', 'XGBoost','Satellite')
exp_xgboost_outdoor = prep_cv_class('output/classification_resampling/exp_outdoor_xgboost.csv', 'Expenditure', 'XGBoost','Outdoor')
exp_xgboost_all = prep_cv_class('output/classification_resampling/exp_all_xgboost.csv', 'Expenditure', 'XGBoost','All')

# Income RF
inc_rf_satellite = prep_cv_class('output/classification_resampling/inc_satellite_rf.csv', 'Income', 'RF','Satellite')
inc_rf_outdoor = prep_cv_class('output/classification_resampling/inc_outdoor_rf.csv', 'Income', 'RF','Outdoor')
inc_rf_all = prep_cv_class('output/classification_resampling/inc_all_rf.csv', 'Income', 'RF','All')

# Income XGBoost
inc_xgboost_satellite = prep_cv_class('output/classification_resampling/inc_satellite_xgboost.csv', 'Income', 'XGBoost','Satellite')
inc_xgboost_outdoor = prep_cv_class('output/classification_resampling/inc_outdoor_xgboost.csv', 'Income', 'XGBoost','Outdoor')
inc_xgboost_all = prep_cv_class('output/classification_resampling/inc_all_xgboost.csv', 'Income', 'XGBoost','All')

# Merge and show
class_resamp = pd.concat([assets_rf_satellite, assets_rf_outdoor, assets_rf_all,
                        assets_xgboost_satellite, assets_xgboost_outdoor, assets_xgboost_all,
                        exp_rf_satellite, exp_rf_outdoor, exp_rf_all,
                        exp_xgboost_satellite, exp_xgboost_outdoor, exp_xgboost_all,
                        inc_rf_satellite, inc_rf_outdoor, inc_rf_all,
                        inc_xgboost_satellite, inc_xgboost_outdoor, inc_xgboost_all],
                        ignore_index=True)
class_resamp
# Out:
#         Outcome    Model   Features     Accuracy Accuracy group 1   F1 group 1
# 0        Assets       RF  Satellite  0.55 (0.03)       0.7 (0.03)  0.59 (0.04)
# 1        Assets       RF    Outdoor  0.59 (0.03)      0.75 (0.03)  0.68 (0.04)
# 2        Assets       RF        All  0.68 (0.04)      0.83 (0.03)  0.79 (0.05)
# 3        Assets  XGBoost  Satellite  0.55 (0.03)       0.7 (0.03)  0.59 (0.05)
# 4        Assets  XGBoost    Outdoor  0.59 (0.04)      0.75 (0.02)  0.68 (0.04)
# 5        Assets  XGBoost        All   0.7 (0.03)      0.84 (0.03)   0.8 (0.04)
# 6   Expenditure       RF  Satellite   0.5 (0.03)      0.67 (0.04)  0.54 (0.06)
# 7   Expenditure       RF    Outdoor  0.52 (0.03)      0.68 (0.03)  0.59 (0.05)
# 8   Expenditure       RF        All  0.58 (0.03)      0.73 (0.03)  0.65 (0.05)
# 9   Expenditure  XGBoost  Satellite  0.49 (0.04)      0.65 (0.04)  0.54 (0.06)
# 10  Expenditure  XGBoost    Outdoor  0.52 (0.03)      0.67 (0.03)  0.59 (0.04)
# ...

# %% [markdown]
# # Article Tables

# %% [markdown]
# ## RF regression + classification, finetuned, test data (main)

# %%
# Regression 
reg_tuned1 = reg_tuned[reg_tuned['model'].str.contains('rf', case=False, na=False)]
reg_tuned1 = pd.melt(reg_tuned1, ['model'])

cond1 = [
    reg_tuned1['variable'].str.contains('assets', case=False, na=False),
    reg_tuned1['variable'].str.contains('exp', case=False, na=False),
    reg_tuned1['variable'].str.contains('inc', case=False, na=False)
]
choice1 = ['Assets', 'Expenditure', 'Income']
cond2 = [
    reg_tuned1['variable'].str.contains('_p', case=False, na=False),
    reg_tuned1['variable'].str.contains('_r2', case=False, na=False),
    reg_tuned1['variable'].str.contains('rmse', case=False, na=False)
]
choice2 = ['p', 'R2', 'RMSE']
cond3 = [
    reg_tuned1['model'].str.contains('Satellite', case=False, na=False),
    reg_tuned1['model'].str.contains('Outdoor', case=False, na=False),
    reg_tuned1['model'].str.contains('Complete', case=False, na=False)
]
choice3 = ['Satellite', 'Outdoor', 'Complete']
reg_tuned1['Outcome'] = np.select(cond1, choice1, default='other')
reg_tuned1['Metric'] = np.select(cond2, choice2, default='other')
reg_tuned1['Features'] = np.select(cond3, choice3, default='other')
reg_tuned1 = reg_tuned1.drop(columns = ['model', 'variable'])
reg_tuned1 = reg_tuned1.pivot(index=['Outcome', 'Features'], columns='Metric', values='value').reset_index()

# Classification
class_tuned1 = class_tuned[class_tuned['model'].str.contains('rf', case=False, na=False)]
class_tuned1 = pd.melt(class_tuned1, ['model'])

cond1 = [
    class_tuned1['variable'].str.contains('assets', case=False, na=False),
    class_tuned1['variable'].str.contains('exp', case=False, na=False),
    class_tuned1['variable'].str.contains('inc', case=False, na=False)
]
choice1 = ['Assets', 'Expenditure', 'Income']
cond2 = [
    class_tuned1['variable'].str.contains('_acc1', case=False, na=False),
    class_tuned1['variable'].str.contains('_acc', case=False, na=False),
    class_tuned1['variable'].str.contains('_f1', case=False, na=False)
]
choice2 = ['Accuracy (bottom 40%)', 'Accuracy', 'F1 (bottom 40%)']
cond3 = [
    class_tuned1['model'].str.contains('Satellite', case=False, na=False),
    class_tuned1['model'].str.contains('Outdoor', case=False, na=False),
    class_tuned1['model'].str.contains('Complete', case=False, na=False)
]
choice3 = ['Satellite', 'Outdoor', 'Complete']
class_tuned1['Outcome'] = np.select(cond1, choice1, default='other')
class_tuned1['Metric'] = np.select(cond2, choice2, default='other')
class_tuned1['Features'] = np.select(cond3, choice3, default='other')
class_tuned1 = class_tuned1.drop(columns = ['model', 'variable'])
class_tuned1 = class_tuned1.pivot(index=['Outcome', 'Features'], columns='Metric', values='value').reset_index()

# Results table
results = reg_tuned1.merge(class_tuned1, on = ['Outcome', 'Features'])
results = results.loc[:, ['Outcome', 'Features', 'p', 'R2', 'RMSE', 'Accuracy', 'Accuracy (bottom 40%)', 'F1 (bottom 40%)']]
results = results.sort_values(by = ['Outcome', 'Features'], ascending = [True, False])

# %%
results = results.style.format(decimal='.', thousands=',', precision=2).hide(axis="index")
results
# Out:
# <style type="text/css">
# </style>
# <table id="T_c521c">
#   <thead>
#     <tr>
#       <th id="T_c521c_level0_col0" class="col_heading level0 col0" >Outcome</th>
#       <th id="T_c521c_level0_col1" class="col_heading level0 col1" >Features</th>
#       <th id="T_c521c_level0_col2" class="col_heading level0 col2" >p</th>
#       <th id="T_c521c_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c521c_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_c521c_level0_col5" class="col_heading level0 col5" >Accuracy</th>
#       <th id="T_c521c_level0_col6" class="col_heading level0 col6" >Accuracy (bottom 40%)</th>
#       <th id="T_c521c_level0_col7" class="col_heading level0 col7" >F1 (bottom 40%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c521c_row0_col0" class="data row0 col0" >Assets</td>
#       <td id="T_c521c_row0_col1" class="data row0 col1" >Satellite</td>
# ...

# %%
print(results.to_latex())
# Out:
# \begin{tabular}{llrrrrrr}
# Outcome & Features & p & R2 & RMSE & Accuracy & Accuracy (bottom 40%) & F1 (bottom 40%) \\
# Assets & Satellite & 0.51 & 0.30 & 0.44 & 0.59 & 0.71 & 0.61 \\
# Assets & Outdoor & 0.70 & 0.50 & 0.37 & 0.59 & 0.73 & 0.68 \\
# Assets & Complete & 0.85 & 0.70 & 0.28 & 0.75 & 0.86 & 0.83 \\
# Expenditure & Satellite & 0.35 & 0.14 & 5,505.40 & 0.47 & 0.63 & 0.47 \\
# Expenditure & Outdoor & 0.45 & 0.24 & 5,162.62 & 0.50 & 0.66 & 0.58 \\
# Expenditure & Complete & 0.57 & 0.38 & 4,684.25 & 0.61 & 0.71 & 0.64 \\
# Income & Satellite & 0.30 & 0.05 & 12,062.84 & 0.47 & 0.62 & 0.51 \\
# Income & Outdoor & 0.41 & 0.10 & 11,735.23 & 0.51 & 0.66 & 0.55 \\
# Income & Complete & 0.50 & 0.16 & 11,323.67 & 0.58 & 0.68 & 0.62 \\
# \end{tabular}

# %% [markdown]
# ## XGBoost regression + classification, finetuned, test data (appendix)

# %%
# Regression 
reg_tuned1 = reg_tuned[reg_tuned['model'].str.contains('xgb', case=False, na=False)]
reg_tuned1 = reg_tuned.iloc[[1,3,5],:]
reg_tuned1 = pd.melt(reg_tuned1, ['model'])

cond1 = [
    reg_tuned1['variable'].str.contains('assets', case=False, na=False),
    reg_tuned1['variable'].str.contains('exp', case=False, na=False),
    reg_tuned1['variable'].str.contains('inc', case=False, na=False)
]
choice1 = ['Assets', 'Expenditure', 'Income']
cond2 = [
    reg_tuned1['variable'].str.contains('_p', case=False, na=False),
    reg_tuned1['variable'].str.contains('_r2', case=False, na=False),
    reg_tuned1['variable'].str.contains('rmse', case=False, na=False)
]
choice2 = ['p', 'R2', 'RMSE']
cond3 = [
    reg_tuned1['model'].str.contains('Satellite', case=False, na=False),
    reg_tuned1['model'].str.contains('Outdoor', case=False, na=False),
    reg_tuned1['model'].str.contains('Complete', case=False, na=False)
]
choice3 = ['Satellite', 'Outdoor', 'Complete']
reg_tuned1['Outcome'] = np.select(cond1, choice1, default='other')
reg_tuned1['Metric'] = np.select(cond2, choice2, default='other')
reg_tuned1['Features'] = np.select(cond3, choice3, default='other')
reg_tuned1 = reg_tuned1.drop(columns = ['model', 'variable'])
reg_tuned1 = reg_tuned1.pivot(index=['Outcome', 'Features'], columns='Metric', values='value').reset_index()

# Classification
class_tuned1 = class_tuned[reg_tuned['model'].str.contains('xgb', case=False, na=False)]
class_tuned1 = pd.melt(class_tuned1, ['model'])

cond1 = [
    class_tuned1['variable'].str.contains('assets', case=False, na=False),
    class_tuned1['variable'].str.contains('exp', case=False, na=False),
    class_tuned1['variable'].str.contains('inc', case=False, na=False)
]
choice1 = ['Assets', 'Expenditure', 'Income']
cond2 = [
    class_tuned1['variable'].str.contains('_acc1', case=False, na=False),
    class_tuned1['variable'].str.contains('_acc', case=False, na=False),
    class_tuned1['variable'].str.contains('_f1', case=False, na=False)
]
choice2 = ['Accuracy (bottom 40%)', 'Accuracy', 'F1 (bottom 40%)']
cond3 = [
    class_tuned1['model'].str.contains('Satellite', case=False, na=False),
    class_tuned1['model'].str.contains('Outdoor', case=False, na=False),
    class_tuned1['model'].str.contains('Complete', case=False, na=False)
]
choice3 = ['Satellite', 'Outdoor', 'Complete']
class_tuned1['Outcome'] = np.select(cond1, choice1, default='other')
class_tuned1['Metric'] = np.select(cond2, choice2, default='other')
class_tuned1['Features'] = np.select(cond3, choice3, default='other')
class_tuned1 = class_tuned1.drop(columns = ['model', 'variable'])
class_tuned1 = class_tuned1.pivot(index=['Outcome', 'Features'], columns='Metric', values='value').reset_index()

# Results table
results = reg_tuned1.merge(class_tuned1, on = ['Outcome', 'Features'])
results = results.loc[:, ['Outcome', 'Features', 'p', 'R2', 'RMSE', 'Accuracy', 'Accuracy (bottom 40%)', 'F1 (bottom 40%)']]
results = results.sort_values(by = ['Outcome', 'Features'], ascending = [True, False])

# %%
results = results.style.format(decimal='.', thousands=',', precision=2).hide(axis="index")
results
# Out:
# <style type="text/css">
# </style>
# <table id="T_d3377">
#   <thead>
#     <tr>
#       <th id="T_d3377_level0_col0" class="col_heading level0 col0" >Outcome</th>
#       <th id="T_d3377_level0_col1" class="col_heading level0 col1" >Features</th>
#       <th id="T_d3377_level0_col2" class="col_heading level0 col2" >p</th>
#       <th id="T_d3377_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d3377_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_d3377_level0_col5" class="col_heading level0 col5" >Accuracy</th>
#       <th id="T_d3377_level0_col6" class="col_heading level0 col6" >Accuracy (bottom 40%)</th>
#       <th id="T_d3377_level0_col7" class="col_heading level0 col7" >F1 (bottom 40%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d3377_row0_col0" class="data row0 col0" >Assets</td>
#       <td id="T_d3377_row0_col1" class="data row0 col1" >Satellite</td>
# ...

# %%
print(results.to_latex())
# Out:
# \begin{tabular}{llrrrrrr}
# Outcome & Features & p & R2 & RMSE & Accuracy & Accuracy (bottom 40%) & F1 (bottom 40%) \\
# Assets & Satellite & 0.54 & 0.30 & 0.43 & 0.58 & 0.73 & 0.61 \\
# Assets & Outdoor & 0.70 & 0.49 & 0.37 & 0.59 & 0.73 & 0.67 \\
# Assets & Complete & 0.84 & 0.70 & 0.29 & 0.74 & 0.86 & 0.83 \\
# Expenditure & Satellite & 0.34 & 0.10 & 5,635.83 & 0.47 & 0.64 & 0.50 \\
# Expenditure & Outdoor & 0.42 & 0.19 & 5,353.11 & 0.47 & 0.66 & 0.54 \\
# Expenditure & Complete & 0.56 & 0.36 & 4,752.38 & 0.61 & 0.74 & 0.68 \\
# Income & Satellite & 0.28 & 0.03 & 12,189.78 & 0.49 & 0.65 & 0.55 \\
# Income & Outdoor & 0.41 & 0.09 & 11,817.62 & 0.44 & 0.57 & 0.47 \\
# Income & Complete & 0.50 & 0.17 & 11,237.70 & 0.55 & 0.67 & 0.61 \\
# \end{tabular}

# %% [markdown]
# ## RF regression + classification, not finetuned, test data (appendix)

# %%
# Regression 
reg_notuned1 = reg_notuned[reg_notuned['model'].str.contains('rf', case=False, na=False)]
reg_notuned1 = pd.melt(reg_notuned1, ['model'])

cond1 = [
    reg_notuned1['variable'].str.contains('assets', case=False, na=False),
    reg_notuned1['variable'].str.contains('exp', case=False, na=False),
    reg_notuned1['variable'].str.contains('inc', case=False, na=False)
]
choice1 = ['Assets', 'Expenditure', 'Income']
cond2 = [
    reg_notuned1['variable'].str.contains('_p', case=False, na=False),
    reg_notuned1['variable'].str.contains('_r2', case=False, na=False),
    reg_notuned1['variable'].str.contains('rmse', case=False, na=False)
]
choice2 = ['p', 'R2', 'RMSE']
cond3 = [
    reg_notuned1['model'].str.contains('Satellite', case=False, na=False),
    reg_notuned1['model'].str.contains('Outdoor', case=False, na=False),
    reg_notuned1['model'].str.contains('Complete', case=False, na=False)
]
choice3 = ['Satellite', 'Outdoor', 'Complete']
reg_notuned1['Outcome'] = np.select(cond1, choice1, default='other')
reg_notuned1['Metric'] = np.select(cond2, choice2, default='other')
reg_notuned1['Features'] = np.select(cond3, choice3, default='other')
reg_notuned1 = reg_notuned1.drop(columns = ['model', 'variable'])
reg_notuned1 = reg_notuned1.pivot(index=['Outcome', 'Features'], columns='Metric', values='value').reset_index()

# Classification
class_notuned1 = class_notuned[class_notuned['model'].str.contains('rf', case=False, na=False)]
class_notuned1 = pd.melt(class_notuned1, ['model'])

cond1 = [
    class_notuned1['variable'].str.contains('assets', case=False, na=False),
    class_notuned1['variable'].str.contains('exp', case=False, na=False),
    class_notuned1['variable'].str.contains('inc', case=False, na=False)
]
choice1 = ['Assets', 'Expenditure', 'Income']
cond2 = [
    class_notuned1['variable'].str.contains('_acc1', case=False, na=False),
    class_notuned1['variable'].str.contains('_acc', case=False, na=False),
    class_notuned1['variable'].str.contains('_f1', case=False, na=False)
]
choice2 = ['Accuracy (bottom 40%)', 'Accuracy', 'F1 (bottom 40%)']
cond3 = [
    class_notuned1['model'].str.contains('Satellite', case=False, na=False),
    class_notuned1['model'].str.contains('Outdoor', case=False, na=False),
    class_notuned1['model'].str.contains('Complete', case=False, na=False)
]
choice3 = ['Satellite', 'Outdoor', 'Complete']
class_notuned1['Outcome'] = np.select(cond1, choice1, default='other')
class_notuned1['Metric'] = np.select(cond2, choice2, default='other')
class_notuned1['Features'] = np.select(cond3, choice3, default='other')
class_notuned1 = class_notuned1.drop(columns = ['model', 'variable'])
class_notuned1 = class_notuned1.pivot(index=['Outcome', 'Features'], columns='Metric', values='value').reset_index()

# Results table
results = reg_notuned1.merge(class_notuned1, on = ['Outcome', 'Features'])
results = results.loc[:, ['Outcome', 'Features', 'p', 'R2', 'RMSE', 'Accuracy', 'Accuracy (bottom 40%)', 'F1 (bottom 40%)']]
results = results.sort_values(by = ['Outcome', 'Features'], ascending = [True, False])

# %%
results = results.style.format(decimal='.', thousands=',', precision=2).hide(axis="index")
results
# Out:
# <style type="text/css">
# </style>
# <table id="T_ef574">
#   <thead>
#     <tr>
#       <th id="T_ef574_level0_col0" class="col_heading level0 col0" >Outcome</th>
#       <th id="T_ef574_level0_col1" class="col_heading level0 col1" >Features</th>
#       <th id="T_ef574_level0_col2" class="col_heading level0 col2" >p</th>
#       <th id="T_ef574_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_ef574_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_ef574_level0_col5" class="col_heading level0 col5" >Accuracy</th>
#       <th id="T_ef574_level0_col6" class="col_heading level0 col6" >Accuracy (bottom 40%)</th>
#       <th id="T_ef574_level0_col7" class="col_heading level0 col7" >F1 (bottom 40%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ef574_row0_col0" class="data row0 col0" >Assets</td>
#       <td id="T_ef574_row0_col1" class="data row0 col1" >Satellite</td>
# ...

# %%
print(results.to_latex())
# Out:
# \begin{tabular}{llrrrrrr}
# Outcome & Features & p & R2 & RMSE & Accuracy & Accuracy (bottom 40%) & F1 (bottom 40%) \\
# Assets & Satellite & 0.47 & 0.26 & 0.45 & 0.57 & 0.68 & 0.57 \\
# Assets & Outdoor & 0.70 & 0.47 & 0.38 & 0.62 & 0.74 & 0.69 \\
# Assets & Complete & 0.83 & 0.65 & 0.31 & 0.71 & 0.83 & 0.80 \\
# Expenditure & Satellite & 0.29 & 0.07 & 5,737.62 & 0.48 & 0.65 & 0.51 \\
# Expenditure & Outdoor & 0.45 & 0.21 & 5,292.54 & 0.54 & 0.69 & 0.59 \\
# Expenditure & Complete & 0.53 & 0.35 & 4,786.93 & 0.56 & 0.69 & 0.60 \\
# Income & Satellite & 0.26 & 0.03 & 12,164.88 & 0.46 & 0.60 & 0.49 \\
# Income & Outdoor & 0.34 & 0.06 & 11,964.40 & 0.45 & 0.61 & 0.50 \\
# Income & Complete & 0.43 & 0.14 & 11,480.42 & 0.53 & 0.66 & 0.58 \\
# \end{tabular}

# %% [markdown]
# ## XGBoost regression + classification, not finetuned, test data (appendix)

# %%
# Regression 
reg_notuned1 = reg_notuned[reg_notuned['model'].str.contains('xgb', case=False, na=False)]
reg_notuned1 = pd.melt(reg_notuned1, ['model'])

cond1 = [
    reg_notuned1['variable'].str.contains('assets', case=False, na=False),
    reg_notuned1['variable'].str.contains('exp', case=False, na=False),
    reg_notuned1['variable'].str.contains('inc', case=False, na=False)
]
choice1 = ['Assets', 'Expenditure', 'Income']
cond2 = [
    reg_notuned1['variable'].str.contains('_p', case=False, na=False),
    reg_notuned1['variable'].str.contains('_r2', case=False, na=False),
    reg_notuned1['variable'].str.contains('rmse', case=False, na=False)
]
choice2 = ['p', 'R2', 'RMSE']
cond3 = [
    reg_notuned1['model'].str.contains('Satellite', case=False, na=False),
    reg_notuned1['model'].str.contains('Outdoor', case=False, na=False),
    reg_notuned1['model'].str.contains('Complete', case=False, na=False)
]
choice3 = ['Satellite', 'Outdoor', 'Complete']
reg_notuned1['Outcome'] = np.select(cond1, choice1, default='other')
reg_notuned1['Metric'] = np.select(cond2, choice2, default='other')
reg_notuned1['Features'] = np.select(cond3, choice3, default='other')
reg_notuned1 = reg_notuned1.drop(columns = ['model', 'variable'])
reg_notuned1 = reg_notuned1.pivot(index=['Outcome', 'Features'], columns='Metric', values='value').reset_index()

# Classification
class_notuned1 = class_notuned[class_notuned['model'].str.contains('xgb', case=False, na=False)]
class_notuned1 = pd.melt(class_notuned1, ['model'])

cond1 = [
    class_notuned1['variable'].str.contains('assets', case=False, na=False),
    class_notuned1['variable'].str.contains('exp', case=False, na=False),
    class_notuned1['variable'].str.contains('inc', case=False, na=False)
]
choice1 = ['Assets', 'Expenditure', 'Income']
cond2 = [
    class_notuned1['variable'].str.contains('_acc1', case=False, na=False),
    class_notuned1['variable'].str.contains('_acc', case=False, na=False),
    class_notuned1['variable'].str.contains('_f1', case=False, na=False)
]
choice2 = ['Accuracy (bottom 40%)', 'Accuracy', 'F1 (bottom 40%)']
cond3 = [
    class_notuned1['model'].str.contains('Satellite', case=False, na=False),
    class_notuned1['model'].str.contains('Outdoor', case=False, na=False),
    class_notuned1['model'].str.contains('Complete', case=False, na=False)
]
choice3 = ['Satellite', 'Outdoor', 'Complete']
class_notuned1['Outcome'] = np.select(cond1, choice1, default='other')
class_notuned1['Metric'] = np.select(cond2, choice2, default='other')
class_notuned1['Features'] = np.select(cond3, choice3, default='other')
class_notuned1 = class_notuned1.drop(columns = ['model', 'variable'])
class_notuned1 = class_notuned1.pivot(index=['Outcome', 'Features'], columns='Metric', values='value').reset_index()

# Results table
results = reg_notuned1.merge(class_notuned1, on = ['Outcome', 'Features'])
results = results.loc[:, ['Outcome', 'Features', 'p', 'R2', 'RMSE', 'Accuracy', 'Accuracy (bottom 40%)', 'F1 (bottom 40%)']]
results = results.sort_values(by = ['Outcome', 'Features'], ascending = [True, False])

# %%
results = results.style.format(decimal='.', thousands=',', precision=2).hide(axis="index")
results
# Out:
# <style type="text/css">
# </style>
# <table id="T_51b44">
#   <thead>
#     <tr>
#       <th id="T_51b44_level0_col0" class="col_heading level0 col0" >Outcome</th>
#       <th id="T_51b44_level0_col1" class="col_heading level0 col1" >Features</th>
#       <th id="T_51b44_level0_col2" class="col_heading level0 col2" >p</th>
#       <th id="T_51b44_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_51b44_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_51b44_level0_col5" class="col_heading level0 col5" >Accuracy</th>
#       <th id="T_51b44_level0_col6" class="col_heading level0 col6" >Accuracy (bottom 40%)</th>
#       <th id="T_51b44_level0_col7" class="col_heading level0 col7" >F1 (bottom 40%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_51b44_row0_col0" class="data row0 col0" >Assets</td>
#       <td id="T_51b44_row0_col1" class="data row0 col1" >Satellite</td>
# ...

# %%
print(results.to_latex())
# Out:
# \begin{tabular}{llrrrrrr}
# Outcome & Features & p & R2 & RMSE & Accuracy & Accuracy (bottom 40%) & F1 (bottom 40%) \\
# Assets & Satellite & 0.48 & 0.26 & 0.45 & 0.55 & 0.67 & 0.58 \\
# Assets & Outdoor & 0.68 & 0.45 & 0.39 & 0.62 & 0.75 & 0.70 \\
# Assets & Complete & 0.83 & 0.67 & 0.30 & 0.74 & 0.85 & 0.82 \\
# Expenditure & Satellite & 0.30 & 0.06 & 5,769.44 & 0.49 & 0.64 & 0.50 \\
# Expenditure & Outdoor & 0.42 & 0.20 & 5,310.43 & 0.53 & 0.68 & 0.58 \\
# Expenditure & Complete & 0.49 & 0.30 & 4,979.12 & 0.58 & 0.69 & 0.62 \\
# Income & Satellite & 0.27 & 0.03 & 12,186.65 & 0.52 & 0.65 & 0.55 \\
# Income & Outdoor & 0.36 & 0.05 & 12,059.62 & 0.47 & 0.60 & 0.53 \\
# Income & Complete & 0.43 & 0.12 & 11,622.79 & 0.53 & 0.65 & 0.59 \\
# \end{tabular}

# %% [markdown]
# ## RF regression + classification, not finetuned, resampling (appendix)

# %%
# Regression
reg_resamp1 = reg_resamp[reg_resamp['Model'] == 'RF']
reg_resamp1 = reg_resamp1.drop(columns = 'Model')
reg_resamp1 = reg_resamp1.rename(columns={'rho': 'p'})

# Classification
class_resamp1 = class_resamp[reg_resamp['Model'] == 'RF']
rclass_resamp1 = class_resamp1.drop(columns = 'Model')
rclass_resamp1 = class_resamp1.rename(columns={'Accuracy group 1': 'Accuracy (bottom 40%)', 'F1 group 1': 'F1 (bottom 40%)'})

# Results table
results = reg_resamp1.merge(rclass_resamp1, on = ['Outcome', 'Features'])
results = results.loc[:, ['Outcome', 'Features', 'p', 'R2', 'RMSE', 'Accuracy', 'Accuracy (bottom 40%)', 'F1 (bottom 40%)']]
results = results.sort_values(by = ['Outcome', 'Features'], ascending = [True, False])

# %%
results = results.style.format(decimal='.', thousands=',', precision=2).hide(axis="index")
results
# Out:
# <style type="text/css">
# </style>
# <table id="T_6493f">
#   <thead>
#     <tr>
#       <th id="T_6493f_level0_col0" class="col_heading level0 col0" >Outcome</th>
#       <th id="T_6493f_level0_col1" class="col_heading level0 col1" >Features</th>
#       <th id="T_6493f_level0_col2" class="col_heading level0 col2" >p</th>
#       <th id="T_6493f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_6493f_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_6493f_level0_col5" class="col_heading level0 col5" >Accuracy</th>
#       <th id="T_6493f_level0_col6" class="col_heading level0 col6" >Accuracy (bottom 40%)</th>
#       <th id="T_6493f_level0_col7" class="col_heading level0 col7" >F1 (bottom 40%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6493f_row0_col0" class="data row0 col0" >Assets</td>
#       <td id="T_6493f_row0_col1" class="data row0 col1" >Satellite</td>
# ...

# %%
print(results.to_latex())
# Out:
# \begin{tabular}{llllllll}
# Outcome & Features & p & R2 & RMSE & Accuracy & Accuracy (bottom 40%) & F1 (bottom 40%) \\
# Assets & Satellite & 0.48 (0.06) & 0.26 (0.05) & 0.43 (0.01) & 0.55 (0.03) & 0.7 (0.03) & 0.59 (0.04) \\
# Assets & Outdoor & 0.66 (0.03) & 0.44 (0.04) & 0.37 (0.02) & 0.59 (0.03) & 0.75 (0.03) & 0.68 (0.04) \\
# Assets & All & 0.79 (0.03) & 0.62 (0.04) & 0.31 (0.02) & 0.68 (0.04) & 0.83 (0.03) & 0.79 (0.05) \\
# Expenditure & Satellite & 0.39 (0.07) & 0.1 (0.05) & 6,013.12 (1,156.43) & 0.5 (0.03) & 0.67 (0.04) & 0.54 (0.06) \\
# Expenditure & Outdoor & 0.49 (0.03) & 0.2 (0.06) & 5,706.14 (1,198.73) & 0.52 (0.03) & 0.68 (0.03) & 0.59 (0.05) \\
# Expenditure & All & 0.59 (0.04) & 0.28 (0.08) & 5,413.61 (1,255.15) & 0.58 (0.03) & 0.73 (0.03) & 0.65 (0.05) \\
# Income & Satellite & 0.33 (0.09) & 0.04 (0.05) & 8,325.99 (1,635.86) & 0.49 (0.04) & 0.63 (0.04) & 0.53 (0.05) \\
# ...

# %% [markdown]
# ## XGBoost regression + classification, not finetuned, resampling (appendix)

# %%
# Regression
reg_resamp1 = reg_resamp[reg_resamp['Model'] == 'XGBoost']
reg_resamp1 = reg_resamp1.drop(columns = 'Model')
reg_resamp1 = reg_resamp1.rename(columns={'rho': 'p'})

# Classification
class_resamp1 = class_resamp[reg_resamp['Model'] == 'XGBoost']
rclass_resamp1 = class_resamp1.drop(columns = 'Model')
rclass_resamp1 = class_resamp1.rename(columns={'Accuracy group 1': 'Accuracy (bottom 40%)', 'F1 group 1': 'F1 (bottom 40%)'})

# Results table
results = reg_resamp1.merge(rclass_resamp1, on = ['Outcome', 'Features'])
results = results.loc[:, ['Outcome', 'Features', 'p', 'R2', 'RMSE', 'Accuracy', 'Accuracy (bottom 40%)', 'F1 (bottom 40%)']]
results = results.sort_values(by = ['Outcome', 'Features'], ascending = [True, False])

# %%
results = results.style.format(decimal='.', thousands=',', precision=2).hide(axis="index")
results
# Out:
# <style type="text/css">
# </style>
# <table id="T_6bc5c">
#   <thead>
#     <tr>
#       <th id="T_6bc5c_level0_col0" class="col_heading level0 col0" >Outcome</th>
#       <th id="T_6bc5c_level0_col1" class="col_heading level0 col1" >Features</th>
#       <th id="T_6bc5c_level0_col2" class="col_heading level0 col2" >p</th>
#       <th id="T_6bc5c_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_6bc5c_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_6bc5c_level0_col5" class="col_heading level0 col5" >Accuracy</th>
#       <th id="T_6bc5c_level0_col6" class="col_heading level0 col6" >Accuracy (bottom 40%)</th>
#       <th id="T_6bc5c_level0_col7" class="col_heading level0 col7" >F1 (bottom 40%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6bc5c_row0_col0" class="data row0 col0" >Assets</td>
#       <td id="T_6bc5c_row0_col1" class="data row0 col1" >Satellite</td>
# ...

# %%
print(results.to_latex())
# Out:
# \begin{tabular}{llllllll}
# Outcome & Features & p & R2 & RMSE & Accuracy & Accuracy (bottom 40%) & F1 (bottom 40%) \\
# Assets & Satellite & 0.48 (0.06) & 0.26 (0.05) & 0.43 (0.02) & 0.55 (0.03) & 0.7 (0.03) & 0.59 (0.05) \\
# Assets & Outdoor & 0.66 (0.04) & 0.44 (0.04) & 0.37 (0.01) & 0.59 (0.04) & 0.75 (0.02) & 0.68 (0.04) \\
# Assets & All & 0.8 (0.03) & 0.63 (0.04) & 0.3 (0.02) & 0.7 (0.03) & 0.84 (0.03) & 0.8 (0.04) \\
# Expenditure & Satellite & 0.37 (0.07) & 0.09 (0.04) & 6,070.5 (1,159.84) & 0.49 (0.04) & 0.65 (0.04) & 0.54 (0.06) \\
# Expenditure & Outdoor & 0.48 (0.04) & 0.18 (0.06) & 5,759.33 (1,202.16) & 0.52 (0.03) & 0.67 (0.03) & 0.59 (0.04) \\
# Expenditure & All & 0.56 (0.05) & 0.26 (0.09) & 5,493.67 (1,286.49) & 0.58 (0.03) & 0.72 (0.03) & 0.65 (0.05) \\
# Income & Satellite & 0.31 (0.09) & 0.03 (0.05) & 8,371.83 (1,666.63) & 0.47 (0.04) & 0.61 (0.04) & 0.53 (0.06) \\
# ...

# %% [markdown]
# # Scatterplot

# %%
# Read data
test_rf = pd.read_csv('output/regression_tuning/test_results_rf.csv')
test_rf['Algorithm'] = "RF"
test_xgboost = pd.read_csv('output/regression_tuning/test_results_xgboost.csv')
test_xgboost['Algorithm'] = "XGBoost"

# %%
# True df
true_all = test_rf[['household', 'assets_true', 'exp_true', 'inc_true']]
true_all = pd.melt(true_all, id_vars = ['household'], value_name='Observed')
true_all['Outcome'] = ['Assets' if ('assets' in i) else 'Expenditure' if ('exp' in i) else 'Income' for i in true_all['variable']]

# %%
# Model df
test_all = pd.concat([test_rf, test_xgboost])
test_all = test_all.loc[:,[False if 'true' in i else True for i in test_all.columns]]
test_all = pd.melt(test_all, id_vars = ['household', 'Algorithm'], value_name='Predicted')
test_all['Outcome'] = ['Assets' if ('assets' in i) else 'Expenditure' if ('exp' in i) else 'Income' for i in test_all['variable']]
test_all['Model'] = ['Satellite' if ('sat' in i) else 'Outdoor' if ('outd' in i) else 'Complete' for i in test_all['variable']]
test_all = test_all.drop('variable', axis=1)

# %%
# Merge
scatter = pd.merge(test_all, true_all, how='left', on=['household', 'Outcome'])

# %%
# Assets scatter
def const_line(*args, **kwargs):
    x = [-1.4, 1.4]
    y = [-1.4, 1.4]
    plt.plot(x, y, color='grey', linewidth=0.8, linestyle='dashed')
    
scatter_plot = scatter.loc[scatter.Outcome=='Assets']
g = sns.FacetGrid(scatter_plot, row='Algorithm', col='Model', height=3, aspect=1)
g.map(const_line)
g.map(sns.scatterplot, "Predicted", "Observed")
g.set_titles(row_template = '{row_name}', col_template = '{col_name}')

# %%
# Write to disk
fig = g.fig
fig.savefig("figures/scatter_assets.png", dpi=300) 
del(g, fig, const_line, scatter_plot)

# %%
# Expenditure scatter
def const_line(*args, **kwargs):
    x = [0, 21000]
    y = [0, 21000]
    plt.plot(x, y, color='grey', linewidth=0.8, linestyle='dashed')
    
scatter_plot = scatter.loc[scatter.Outcome=='Expenditure']
g = sns.FacetGrid(scatter_plot, row='Algorithm', col='Model', height=3, aspect=1)
g.map(const_line)
g.map(sns.scatterplot, "Predicted", "Observed")
g.set_titles(row_template = '{row_name}', col_template = '{col_name}')

# %%
# Write to disk
fig = g.fig
fig.savefig("figures/scatter_expenditure.png", dpi=300)
del(g, fig, const_line, scatter_plot)

# %%
# Income scatter
def const_line(*args, **kwargs):
    x = [-1000, 25000]
    y = [-1000, 25000]
    plt.plot(x, y, color='grey', linewidth=0.8, linestyle='dashed')
    
scatter_plot = scatter.loc[scatter.Outcome=='Income']
g = sns.FacetGrid(scatter_plot, row='Algorithm', col='Model', height=3, aspect=1)
g.map(const_line)
g.map(sns.scatterplot, "Predicted", "Observed")
g.set_titles(row_template = '{row_name}', col_template = '{col_name}')

# %%
# Write to disk
fig = g.fig
fig.savefig("figures/scatter_income.png", dpi=300)
del(g, fig, const_line, scatter_plot)
